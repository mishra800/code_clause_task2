# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
pd.set_option('max_rows', None)
pd.set_option('max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[28], line 4
#       2 from mlxtend.frequent_patterns import apriori
#       3 from mlxtend.frequent_patterns import association_rules
# ----> 4 pd.set_option('max_rows', None)
#       5 pd.set_option('max_columns', None)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_config\config.py:272, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     271 def __call__(self, *args, **kwds) -> T:
# --> 272     return self.__func__(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_config\config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
#     169     o = _get_registered_option(key)
#     170     if o and o.validator:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_config\config.py:134, in _get_single_key(pat, silent)
#     132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
# --> 134     raise OptionError("Pattern matched multiple keys")
#     135 key = keys[0]
#     137 if not silent:
#
# OptionError: Pattern matched multiple keys

# %%
df = pd.read_csv("data.csv",encoding='latin1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df['Description'] = df['Description'].str.strip() #remove empty spaces
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True) #drop rows that dont have invoice numbers. 
df['InvoiceNo'] = df['InvoiceNo'].astype('str') #convert Invoice No to String
df = df[~df['InvoiceNo'].str.contains('C')] #drop rows with invoice containg C which means Credit Tran

# %%
df.shape
# Out:
# (532621, 8)

# %%
basket = (df[df['Country'] =="France"]        #get data for samples which have Country as France
          .groupby(['InvoiceNo', 'Description'])['Quantity'] #group them on InvoiceNo and Description based on Quantity
          .sum().unstack().reset_index().fillna(0) #sum the quantity, unstack them, fill 0 to nan values. 
          .set_index('InvoiceNo')) #set the index as Invoice Number

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# 536852                                 0.0
# 536974                                 0.0
# 537065                                 0.0
# 537463                                 0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                       0.0                          0.0
# 536852                                       0.0                          0.0
# 536974                                       0.0                          0.0
# 537065                                       0.0                          0.0
# 537463                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                             0.0                                 0.0
# 536852                             0.0                                 0.0
# 536974                             0.0                                 0.0
# 537065                             0.0                                 0.0
# 537463                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                 0.0  ...                          0.0
# 536852                                 0.0  ...                          0.0
# 536974                                 0.0  ...                          0.0
# 537065                                 0.0  ...                          0.0
# 537463                                 0.0  ...                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                           0.0                        0.0
# 536852                           0.0                        0.0
# 536974                           0.0                        0.0
# 537065                           0.0                        0.0
# 537463                           0.0                        0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                             0.0                         0.0
# 536852                             0.0                         0.0
# 536974                             0.0                         0.0
# 537065                             0.0                         0.0
# 537463                             0.0                         0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                   0.0
# 536852                                   0.0
# 536974                                   0.0
# 537065                                   0.0
# 537463                                   0.0
#
# [5 rows x 1563 columns]

# %%
basket.shape
# Out:
# (392, 1563)

# %%
#below function converts a values < 0 to 0 and value greater than equal 1 to 1.  
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
#apply function to data using applymap.
basket_sets = basket.applymap(encode_units)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_10188\741586795.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_sets = basket.applymap(encode_units)

# %%
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# 536852                                   0
# 536974                                   0
# 537065                                   0
# 537463                                   0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                         0                            0
# 536852                                         0                            0
# 536974                                         0                            0
# 537065                                         0                            0
# 537463                                         0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                               0                                   0
# 536852                               0                                   0
# 536974                               0                                   0
# 537065                               0                                   0
# 537463                               0                                   0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                   0  ...                            0
# 536852                                   0  ...                            0
# 536974                                   0  ...                            0
# 537065                                   0  ...                            0
# 537463                                   0  ...                            0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                             0                          0
# 536852                             0                          0
# 536974                             0                          0
# 537065                             0                          0
# 537463                             0                          0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                               0                           0
# 536852                               0                           0
# 536974                               0                           0
# 537065                               0                           0
# 537463                               0                           0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                                 0                               0
# 536852                                 0                               0
# 536974                                 0                               0
# 537065                                 0                               0
# 537463                                 0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                     0
# 536852                                     0
# 536974                                     0
# 537065                                     0
# 537463                                     0
#
# [5 rows x 1563 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
# Out:
# C:\Users\abhis\AppData\Roaming\Python\Python311\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                     antecedents                   consequents  \
# 0   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 1  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 2    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)
# 3  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)
# 4                     (POSTAGE)  (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.102041            0.096939  0.073980    0.725000  7.478947
# 1            0.096939            0.102041  0.073980    0.763158  7.478947
# 2            0.094388            0.096939  0.079082    0.837838  8.642959
# 3            0.096939            0.094388  0.079082    0.815789  8.642959
# 4            0.765306            0.096939  0.084184    0.110000  1.134737
#
#    leverage  conviction  zhangs_metric
# 0  0.064088    3.283859       0.964734
# 1  0.064088    3.791383       0.959283
# 2  0.069932    5.568878       0.976465
# 3  0.069932    4.916181       0.979224
# 4  0.009996    1.014676       0.505929

# %%
rules[(rules['lift'] >= 6) &(rules['confidence'] >= 0.8)]
# Out:
#                                            antecedents  \
# 2                           (ALARM CLOCK BAKELIKE RED)
# 3                         (ALARM CLOCK BAKELIKE GREEN)
# 75                     (SET/6 RED SPOTTY PAPER PLATES)
# 76                       (SET/6 RED SPOTTY PAPER CUPS)
# 77                     (SET/6 RED SPOTTY PAPER PLATES)
# 79                 (ALARM CLOCK BAKELIKE RED, POSTAGE)
# 80               (POSTAGE, ALARM CLOCK BAKELIKE GREEN)
# 114             (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)
# 116           (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)
# 119                    (SET/6 RED SPOTTY PAPER PLATES)
# 120  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 121  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 122  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 126  (SET/6 RED SPOTTY PAPER CUPS, POSTAGE, SET/20 ...
# 129  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS, ...
#
#                                 consequents  antecedent support  \
# 2              (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 3                (ALARM CLOCK BAKELIKE RED)            0.096939
# 75     (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 76          (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 77            (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 79             (ALARM CLOCK BAKELIKE GREEN)            0.086735
# 80               (ALARM CLOCK BAKELIKE RED)            0.084184
# 114         (SET/6 RED SPOTTY PAPER PLATES)            0.117347
# 116           (SET/6 RED SPOTTY PAPER CUPS)            0.107143
# 119  (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)            0.127551
# 120         (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 121    (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 122           (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 126         (SET/6 RED SPOTTY PAPER PLATES)            0.084184
# 129           (SET/6 RED SPOTTY PAPER CUPS)            0.084184
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 2              0.096939  0.079082    0.837838  8.642959  0.069932    5.568878
# 3              0.094388  0.079082    0.815789  8.642959  0.069932    4.916181
# 75             0.132653  0.102041    0.800000  6.030769  0.085121    4.336735
# 76             0.127551  0.122449    0.888889  6.968889  0.104878    7.852041
# 77             0.137755  0.122449    0.960000  6.968889  0.104878   21.556122
# 79             0.096939  0.071429    0.823529  8.495356  0.063021    5.117347
# 80             0.094388  0.071429    0.848485  8.989353  0.063483    5.977041
# 114            0.127551  0.102041    0.869565  6.817391  0.087073    6.688776
# 116            0.137755  0.102041    0.952381  6.913580  0.087281   18.107143
# 119            0.117347  0.102041    0.800000  6.817391  0.087073    4.413265
# 120            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 121            0.132653  0.099490    0.812500  6.125000  0.083247    4.625850
# 122            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# 126            0.127551  0.081633    0.969697  7.602424  0.070895   28.790816
# 129            0.137755  0.081633    0.969697  7.039282  0.070036   28.454082
#
#      zhangs_metric
# 2         0.976465
# 3         0.979224
# 75        0.956140
# 76        0.993343
# 77        0.981725
# 79        0.966081
# 80        0.970454
# 114       0.966763
# 116       0.958000
# 119       0.978070
# 120       0.967949
# 121       0.953488
# 122       0.956294
# 126       0.948294
# 129       0.936804

# %%
Conclusion
In looking at the rules, it seems that the green and red alarm clocks are purchased together and the red paper cups, napkins and plates are purchased together in a manner that is higher than the overall probability would suggest.
# Out:
#   Cell In[27], line 2
#     In looking at the rules, it seems that the green and red alarm clocks are purchased together and the red paper cups, napkins and plates are purchased together in a manner that is higher than the overall probability would suggest.
#        ^
# SyntaxError: invalid syntax
